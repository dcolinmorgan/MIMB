# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('~/Downloads/sigtestR_dcm/anova.txt',sep='\t',header=None,usecols=[0,1,2],names=['class','group','pval'])
data1=pd.read_csv('~/Downloads/sigtestR_dcm/burts3.txt',sep='\t',header=None,usecols=[0,1,2,3,5],names=['class','group','1v2','1v3','2v3'])
data2=pd.read_csv('~/Downloads/sigtestR_dcm/burts4.txt',sep='\t',header=None,usecols=[0,1,2,3,4,6,7,10],names=['class','group','1v2','1v3','1v4','2v3','2v4','3v4'])
data3=pd.read_csv('~/Downloads/sigtestR_dcm/burts5.txt',sep='\t',header=None,usecols=[0,1,2,3,4,5,7,8,9,12,13,17],names=['class','group','1v2','1v3','1v4','1v5','2v3','2v4','2v5','3v4','3v5','4v5'])

# %%
data['pval']=data['pval'].replace([np.inf, -np.inf], np.nan, inplace=False)
# data=data[data.pval!=0].dropna()
data['pval']=data['pval'].replace(0,1e-300)
data['log10_pval']=np.log10(data['pval'])

# %%
data['class1']=data['group'].str.split('_',expand=True)[0]
data['class2']=data['group'].str.split('_',expand=True)[1]

# %%
np.unique(data['group'])
# Out:
# array(['all_all', 'all_tri1', 'all_tri2', 'all_tri3', 'high_all',
#        'high_tri1', 'high_tri2', 'high_tri3', 'norm_all', 'norm_tri1',
#        'norm_tri2', 'norm_tri3'], dtype=object)

# %%
data
# Out:
#               class      group           pval  log10_pval class1 class2
# 0    prop_messaging    all_all  1.000000e-300 -300.000000    all    all
# 1    prop_messaging   all_tri1  1.000000e-300 -300.000000    all   tri1
# 2    prop_messaging   all_tri2  1.000000e-300 -300.000000    all   tri2
# 3    prop_messaging   all_tri3  1.000000e-300 -300.000000    all   tri3
# 4    prop_messaging   norm_all  1.000000e-300 -300.000000   norm    all
# ..              ...        ...            ...         ...    ...    ...
# 367      ttend_tri3  norm_tri3   5.079307e-31  -30.294196   norm   tri3
# 368      ttend_tri3   high_all   1.370805e-02   -1.863024   high    all
# 369      ttend_tri3  high_tri1   1.863895e-07   -6.729579   high   tri1
# 370      ttend_tri3  high_tri2   2.983065e-03   -2.525337   high   tri2
# 371      ttend_tri3  high_tri3   1.396699e-01   -0.854897   high   tri3
#
# [372 rows x 6 columns]

# %%
# sns.set(rc={'figure.figsize':(11.7,8.27)})
aa=sns.catplot(kind='violin',data=data,x='pval',y='class',row='class1',col='class2')#, multiple="stack")#,legend_out=True)
aa.axvline(0.05)
aa.savefig("../Downloads/sigtestR_dcm/big_anova.png",dpi=600)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-3000a8f1a56c> in <module>
#       1 # sns.set(rc={'figure.figsize':(11.7,8.27)})
#       2 aa=sns.catplot(kind='violin',data=data,x='pval',y='class',row='class1',col='class2')#, multiple="stack")#,legend_out=True)
# ----> 3 aa.axvline(0.05)
#       4 aa.savefig("../Downloads/sigtestR_dcm/big_anova.png",dpi=600)
#
# AttributeError: 'FacetGrid' object has no attribute 'axvline'

# %%
plt.figure(figsize=(18, 4))
sns.set_style('ticks')
aa=sns.catplot(kind='violin',data=data,x='log10_pval',y='class',row='class1',col='class2')#, multiple="stack")#,legend_out=True)
aa.axvline(0.05)
aa.savefig("../Downloads/sigtestR_dcm/big_log_anova.png",dpi=600)

# %%
data1['class1']=data1['group'].str.split('_',expand=True)[0]
data1['class2']=data1['group'].str.split('_',expand=True)[1]
data1=pd.melt(data1.dropna(),id_vars=['class','class1','class2','group'])

# %%
plt.figure(figsize=(18, 4))
sns.set_style('ticks')
aa=sns.catplot(kind='violin',data=data1,x='value',y='class',cut=0,row='variable',col='group')#, multiple="stack")#,legend_out=True)
aa.savefig("../Downloads/sigtestR_dcm/big_duncan3.png",dpi=1600)

# %%
data2['class1']=data2['group'].str.split('_',expand=True)[0]
data2['class2']=data2['group'].str.split('_',expand=True)[1]
data2=pd.melt(data2.dropna(),id_vars=['class','class1','class2','group'])
plt.figure(figsize=(18, 4))
sns.set_style('ticks')
aa=sns.catplot(kind='violin',data=data2,x='value',y='class',cut=0,row='variable',col='group')#, multiple="stack")#,legend_out=True)
aa.savefig("../Downloads/sigtestR_dcm/big_duncan4.png",dpi=800)

# %%
data3['class1']=data3['group'].str.split('_',expand=True)[0]
data3['class2']=data3['group'].str.split('_',expand=True)[1]
data3=pd.melt(data3.dropna(),id_vars=['class','class1','class2','group'])
plt.figure(figsize=(18, 4))
sns.set_style('ticks')
aa=sns.catplot(kind='violin',data=data3,x='value',y='class',cut=0,row='variable',col='group')#, multiple="stack")#,legend_out=True)
aa.savefig("../Downloads/sigtestR_dcm/big_duncan5.png",dpi=650)

# %%
data3
# Out:
#                class class1 class2      group variable         value
# 0     prop_messaging    all   tri2   all_tri2      1v2  7.605454e-02
# 1     prop_messaging   high   tri1  high_tri1      1v2  7.422728e-04
# 2        prop_visits    all   tri2   all_tri2      1v2  1.638900e-11
# 3        prop_visits   high   tri1  high_tri1      1v2  0.000000e+00
# 4      prop_myrecord    all   tri2   all_tri2      1v2  8.194556e-12
# ..               ...    ...    ...        ...      ...           ...
# 615  se_max_tri3_fin   high   tri1  high_tri1      4v5  1.524521e-07
# 616     ttstart_tri3    all   tri2   all_tri2      4v5  5.477618e-12
# 617     ttstart_tri3   high   tri1  high_tri1      4v5  2.746558e-06
# 618       ttend_tri3    all   tri2   all_tri2      4v5  7.658167e-01
# 619       ttend_tri3   high   tri1  high_tri1      4v5  4.111530e-03
#
# [620 rows x 6 columns]

# %%
# copy text from https://forum.duolingo.com/comment/19825381

# %%
# from googletrans import Translator
from google_trans_new import google_translator  
import pandas as pd
import numpy as np
translator = google_translator()

# %%
translator.translate('för',  lang_tgt='en')
# Out:
# 'for '

# %%
data=pd.read_csv('../Dropbox (Personal)/morgan sharing/Duo_SWE.txt',sep=' : ')
dd=data['Words'].str.split(',').str[0].tolist()#[12]
translate_text = translator.translate(dd, lang_src='swe', lang_tgt='en')  
ee=pd.DataFrame(translate_text.split(','))
ff=ee[ee[0]!="'"]
Duo=pd.DataFrame(dd,ff[0].replace("\'|\[|\]", '', regex=True))

Duo.columns=['swedish']
Duo=Duo.reset_index()
Duo.columns=['english','swedish']
# Duo
for i in range(1,30):
    dd=data['Words'].str.split(',').str[i].tolist()#[12]
    translate_text = translator.translate(dd, lang_src='swe', lang_tgt='en')  
    ee=pd.DataFrame(translate_text.split(','))
    ff=ee[ee[0]!="'"]
    ww=pd.DataFrame(dd,ff[0].replace("\'|\[|\]", '', regex=True))
    Duo.append(ww)
# Out:
# <ipython-input-165-046533a62893>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data=pd.read_csv('../Dropbox (Personal)/morgan sharing/Duo_SWE.txt',sep=' : ')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/Caskroom/miniconda/base/envs/py3/lib/python3.8/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1656
# -> 1657         mgr = BlockManager(blocks, axes)
#    1658         mgr._consolidate_inplace()
#
# /usr/local/Caskroom/miniconda/base/envs/py3/lib/python3.8/site-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, do_integrity_check)
#     138         if do_integrity_check:
# --> 139             self._verify_integrity()
#     140
#
# /usr/local/Caskroom/miniconda/base/envs/py3/lib/python3.8/site-packages/pandas/core/internals/managers.py in _verify_integrity(self)
#     333             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# --> 334                 construction_error(tot_items, block.shape[1:], self.axes)
#     335         if len(self.items) != tot_items:
#
# /usr/local/Caskroom/miniconda/base/envs/py3/lib/python3.8/site-packages/pandas/core/internals/managers.py in construction_error(tot_items, block_shape, axes, e)
#    1693         raise ValueError("Empty data passed with indices specified.")
# -> 1694     raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#    1695
#
# ValueError: Shape of passed values is (66, 1), indices imply (63, 1)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-165-046533a62893> in <module>
#      15     ee=pd.DataFrame(translate_text.split(','))
#      16     ff=ee[ee[0]!="'"]
# ---> 17     ww=pd.DataFrame(dd,ff[0].replace("\'|\[|\]", '', regex=True))
#      18     Duo.append(ww)
#
# /usr/local/Caskroom/miniconda/base/envs/py3/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     486                     mgr = arrays_to_mgr(arrays, columns, index, columns, dtype=dtype)
#     487                 else:
# --> 488                     mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     489             else:
#     490                 mgr = init_dict({}, index, columns, dtype=dtype)
#
# /usr/local/Caskroom/miniconda/base/envs/py3/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_ndarray(values, index, columns, dtype, copy)
#     208         block_values = [values]
#     209
# --> 210     return create_block_manager_from_blocks(block_values, [columns, index])
#     211
#     212
#
# /usr/local/Caskroom/miniconda/base/envs/py3/lib/python3.8/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1662         blocks = [getattr(b, "values", b) for b in blocks]
#    1663         tot_items = sum(b.shape[0] for b in blocks)
# -> 1664         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1665
#    1666
#
# /usr/local/Caskroom/miniconda/base/envs/py3/lib/python3.8/site-packages/pandas/core/internals/managers.py in construction_error(tot_items, block_shape, axes, e)
#    1692     if block_shape[0] == 0:
#    1693         raise ValueError("Empty data passed with indices specified.")
# -> 1694     raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#    1695
#    1696
#
# ValueError: Shape of passed values is (66, 1), indices imply (63, 1)

# %%
data['Words'].str.split(',')#.str[0]
# Out:
# 0     [man,  kvinna,  är,  pojke,  flicka,  jag,  en...
# 1     [vi,  läser,  ni,  kvinnor,  tidning,  de,  mä...
# 2     [hej,  tack,  ja,  nej,  då,  så,  mycket,  va...
# 3     [fisk,  apelsin,  kaffe,  ägg,  kyckling,  dry...
# 4     [katt,  hund,  häst,  fågeln,  fågel,  katten,...
#                             ...
# 61    [gud,  religion,  andlig,  troll,  tomte,  spö...
# 62    [kritiseras,  älskas,  väljs,  höjas,  höjs,  ...
# 63              [skulle,  åka,  börja,  komma,  träffa]
# 64    [företag,  skatt,  ränta,  skuld,  procent,  s...
# 65    [godis,  läsken,  födelsedag,  present,  kalas...
# Name: Words, Length: 66, dtype: object

# %%
dd
# Out:
# [' kvinna',
#  ' läser',
#  ' tack',
#  ' apelsin',
#  ' hund',
#  ' kaffet',
#  ' böcker',
#  ' hans',
#  ' dem',
#  ' på',
#  ' kommer',
#  ' rosa',
#  ' hur',
#  ' i',
#  ' eller',
#  ' eftermiddagen',
#  ' mamma',
#  ' läkare',
#  ' långt',
#  ' ger',
#  ' för',
#  ' hotell',
#  ' sängarna',
#  ' vän',
#  ' bil',
#  ' detta',
#  ' två',
#  ' ställer',
#  ' utbildning',
#  ' drack',
#  ' skriva',
#  ' malmö',
#  ' förstod',
#  ' bullar',
#  ' lyckliga',
#  ' namn',
#  ' kallare',
#  ' regnat',
#  ' ko',
#  ' måste',
#  ' ät',
#  ' låta',
#  ' ringt',
#  ' där',
#  ' träffa',
#  ' trädet',
#  ' står',
#  ' hård',
#  ' även',
#  ' respekt',
#  ' spelarna',
#  ' fram',
#  ' fiol',
#  ' hand',
#  ' krig',
#  ' informationen',
#  ' misslyckat',
#  ' irriterande',
#  ' ha',
#  ' detalj',
#  ' bli',
#  ' religion',
#  ' älskas',
#  ' åka',
#  ' skatt',
#  ' läsken']

# %%
ff[0]
# Out:
# 0        ['Female'
# 1           'read'
# 2      'thank you'
# 3         'orange'
# 4            'dog'
#           ...
# 63    ' religion '
# 64       ' loved '
# 65        ' ride '
# 66         ' tax '
# 67      ' soda ']
# Name: 0, Length: 63, dtype: object

# %%
translate_text
# Out:
# "['Female', 'read', 'thank you', 'orange', 'dog', 'coffee', 'books',' his', '' 'pink', ' How ',' I ',' or ',' the afternoon ',' Mom ',' Doctor ',' Long ',' gives', '', 'hotel', 'Beds',' friend ',' car ' , 'This',' two ',' sets', 'education', 'drank', 'write', 'Malmö', 'understand', 'bunar', 'happy', 'name', 'colder', ' Rained ',' Ko ',' must ',', ',', ',', ',', ',', 'the tree', is', ',' hard ', even', 'respect' , 'players',' front ',' violin ',' hand ',' war ',' information ',' fail ',' annoying ',' have ',' detail ',' become ',' religion ',' loved ',' ride ',' tax ',' soda '] "

# %%
ee
# Out:
#                0
# 0      ['Female'
# 1         'read'
# 2    'thank you'
# 3       'orange'
# 4          'dog'
# ..           ...
# 63  ' religion '
# 64     ' loved '
# 65      ' ride '
# 66       ' tax '
# 67    ' soda ']
#
# [68 rows x 1 columns]

# %%
# ee[ee[0]!="'"]
ee[1:30]
# Out:
#                     0
# 1              'read'
# 2         'thank you'
# 3            'orange'
# 4               'dog'
# 5            'coffee'
# 6             'books'
# 7              ' his'
# 8           '' 'pink'
# 9             ' How '
# 10              ' I '
# 11             ' or '
# 12  ' the afternoon '
# 13            ' Mom '
# 14         ' Doctor '
# 15           ' Long '
# 16           ' gives'
# 17                 ''
# 18            'hotel'
# 19             'Beds'
# 20         ' friend '
# 21           ' car '
# 22             'This'
# 23            ' two '
# 24            ' sets'
# 25        'education'
# 26            'drank'
# 27            'write'
# 28            'Malmö'
# 29       'understand'
